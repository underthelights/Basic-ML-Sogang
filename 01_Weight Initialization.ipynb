# %% [markdown]
# # W = np.random.randn(fan_in, fan_out) * 0.01

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# assume some unit gaussian 500-D input data
D = np.random.randn(1000, 500)
hidden_layer_sizes = [500]*10
#print(hidden_layer_sizes)
#print(len(hidden_layer_sizes))
nonlinearities = ['tanh']*len(hidden_layer_sizes)
#nonlinearities = ['relu']*len(hidden_layer_sizes)
#print(nonlinearities)

# %%
act = {'relu':lambda x: np.maximum(0,x), 'tanh':lambda x:np.tanh(x)}
Hs = {}
for i in range(len(hidden_layer_sizes)):
    X = D if i == 0 else Hs[i-1] # input at this layer
    fan_in = X.shape[1]
    fan_out = hidden_layer_sizes[i]
    print([fan_in, fan_out])
    W = np.random.randn(fan_in, fan_out) * 0.01 # layer initialization, 500x500
    #print([X.shape, W.shape])
    H = np.dot(X,W) # matrix multiply, X: 1000x500, W 500x500
    #print(f'H.shape : {H.shape}')
    H = act[nonlinearities[i]](H)
    Hs[i] = H # cache result on this layer
# Out:
# [500, 500]
# [500, 500]
# [500, 500]
# [500, 500]
# [500, 500]
# [500, 500]
# [500, 500]
# [500, 500]
# [500, 500]
# [500, 500]

# %%
# look at distributions at each layer
print ('input layer had mean %f and std %f' % (np.mean(D), np.std(D)))
layer_means = [np.mean(H) for i,H in Hs.items()]
layer_stds = [np.std(H) for i,H in Hs.items()]
for i,H in Hs.items():
    print ('hidden layer %d had mean %f and std %f' % (i+1, layer_means[i], layer_stds[i]))
    
# plot the means and standard deviations
plt.figure()
plt.subplot(121)
plt.plot(Hs.keys(), layer_means, 'ob-')
plt.title('layer mean')
plt.subplot(122)
plt.plot(Hs.keys(), layer_stds, 'or-')
plt.title('layer std')

# plot the raw distributions
plt.figure()
for i,H in Hs.items():
    plt.subplot(1,len(Hs), i+1)
    plt.hist(H.ravel(), 30, range=(-1,1))
# Out:
# input layer had mean -0.000026 and std 1.000069
# hidden layer 1 had mean -0.000333 and std 0.213261
# hidden layer 2 had mean -0.000002 and std 0.047517
# hidden layer 3 had mean -0.000004 and std 0.010593
# hidden layer 4 had mean -0.000002 and std 0.002381
# hidden layer 5 had mean 0.000000 and std 0.000534
# hidden layer 6 had mean 0.000000 and std 0.000119
# hidden layer 7 had mean -0.000000 and std 0.000027
# hidden layer 8 had mean 0.000000 and std 0.000006
# hidden layer 9 had mean 0.000000 and std 0.000001
# hidden layer 10 had mean 0.000000 and std 0.000000

# %% [markdown]
# # W = np.random.randn(fan_in, fan_out) * 1.0

# %%
act = {'relu':lambda x: np.maximum(0,x), 'tanh':lambda x:np.tanh(x)}
Hs = {}
for i in range(len(hidden_layer_sizes)):
    X = D if i == 0 else Hs[i-1] # input at this layer
    fan_in = X.shape[1]
    fan_out = hidden_layer_sizes[i]
    W = np.random.randn(fan_in, fan_out) * 1.0 # layer initialization
    
    H = np.dot(X,W) # matrix multiply
    H = act[nonlinearities[i]](H)
    Hs[i] = H # cache result on this layer

# %%
# look at distributions at each layer
print ('input layer had mean %f and std %f' % (np.mean(D), np.std(D)))
layer_means = [np.mean(H) for i,H in Hs.items()]
layer_stds = [np.std(H) for i,H in Hs.items()]
for i,H in Hs.items():
    print ('hidden layer %d had mean %f and std %f' % (i+1, layer_means[i], layer_stds[i]))
    
# plot the means and standard deviations
plt.figure()
plt.subplot(121)
plt.plot(Hs.keys(), layer_means, 'ob-')
plt.title('layer mean')
plt.subplot(122)
plt.plot(Hs.keys(), layer_stds, 'or-')
plt.title('layer std')

# plot the raw distributions
plt.figure()
for i,H in Hs.items():
    plt.subplot(1,len(Hs), i+1)
    plt.hist(H.ravel(), 30, range=(-1,1))
# Out:
# input layer had mean -0.000026 and std 1.000069
# hidden layer 1 had mean -0.001047 and std 0.982132
# hidden layer 2 had mean 0.000225 and std 0.981550
# hidden layer 3 had mean -0.001898 and std 0.981751
# hidden layer 4 had mean 0.000671 and std 0.981516
# hidden layer 5 had mean 0.000163 and std 0.981752
# hidden layer 6 had mean 0.000086 and std 0.981682
# hidden layer 7 had mean -0.001470 and std 0.981632
# hidden layer 8 had mean 0.000586 and std 0.981721
# hidden layer 9 had mean -0.001200 and std 0.981592
# hidden layer 10 had mean -0.000626 and std 0.981732

# %% [markdown]
# # W = np.random.randn(fan_in, fan_out) / np.sqrt(fan_in)

# %%
act = {'relu':lambda x: np.maximum(0,x), 'tanh':lambda x:np.tanh(x)}
Hs = {}
for i in range(len(hidden_layer_sizes)):
    X = D if i == 0 else Hs[i-1] # input at this layer
    fan_in = X.shape[1]
    fan_out = hidden_layer_sizes[i]
    W = np.random.randn(fan_in, fan_out) / np.sqrt(fan_in) # layer initialization
    
    H = np.dot(X,W) # matrix multiply
    H = act[nonlinearities[i]](H)
    Hs[i] = H # cache result on this layer

# %%
# look at distributions at each layer
print ('input layer had mean %f and std %f' % (np.mean(D), np.std(D)))
layer_means = [np.mean(H) for i,H in Hs.items()]
layer_stds = [np.std(H) for i,H in Hs.items()]
for i,H in Hs.items():
    print ('hidden layer %d had mean %f and std %f' % (i+1, layer_means[i], layer_stds[i]))
    
# plot the means and standard deviations
plt.figure()
plt.subplot(121)
plt.plot(Hs.keys(), layer_means, 'ob-')
plt.title('layer mean')
plt.subplot(122)
plt.plot(Hs.keys(), layer_stds, 'or-')
plt.title('layer std')

# plot the raw distributions
plt.figure()
for i,H in Hs.items():
    plt.subplot(1,len(Hs), i+1)
    plt.hist(H.ravel(), 30, range=(-1,1))
# Out:
# input layer had mean -0.000026 and std 1.000069
# hidden layer 1 had mean 0.000990 and std 0.627244
# hidden layer 2 had mean -0.000041 and std 0.484814
# hidden layer 3 had mean 0.000887 and std 0.407520
# hidden layer 4 had mean 0.000594 and std 0.358208
# hidden layer 5 had mean -0.000141 and std 0.321634
# hidden layer 6 had mean -0.000480 and std 0.295332
# hidden layer 7 had mean -0.000249 and std 0.273028
# hidden layer 8 had mean -0.000268 and std 0.254748
# hidden layer 9 had mean -0.000277 and std 0.240090
# hidden layer 10 had mean 0.000032 and std 0.226542

# %% [markdown]
# # W = np.random.randn(fan_in, fan_out) / np.sqrt(fan_in/2)

# %%
act = {'relu':lambda x: np.maximum(0,x), 'tanh':lambda x:np.tanh(x)}
Hs = {}
for i in range(len(hidden_layer_sizes)):
    X = D if i == 0 else Hs[i-1] # input at this layer
    fan_in = X.shape[1]
    fan_out = hidden_layer_sizes[i]
    W = np.random.randn(fan_in, fan_out) / np.sqrt(fan_in/2) # layer initialization
    
    H = np.dot(X,W) # matrix multiply
    H = act[nonlinearities[i]](H)
    Hs[i] = H # cache result on this layer

# %%
# look at distributions at each layer
print ('input layer had mean %f and std %f' % (np.mean(D), np.std(D)))
layer_means = [np.mean(H) for i,H in Hs.items()]
layer_stds = [np.std(H) for i,H in Hs.items()]
for i,H in Hs.items():
    print ('hidden layer %d had mean %f and std %f' % (i+1, layer_means[i], layer_stds[i]))
    
# plot the means and standard deviations
plt.figure()
plt.subplot(121)
plt.plot(Hs.keys(), layer_means, 'ob-')
plt.title('layer mean')
plt.subplot(122)
plt.plot(Hs.keys(), layer_stds, 'or-')
plt.title('layer std')

# plot the raw distributions
plt.figure()
for i,H in Hs.items():
    plt.subplot(1,len(Hs), i+1)
    plt.hist(H.ravel(), 30, range=(-1,1))
# Out:
# input layer had mean -0.000026 and std 1.000069
# hidden layer 1 had mean -0.002225 and std 0.721007
# hidden layer 2 had mean -0.000406 and std 0.633240
# hidden layer 3 had mean 0.000093 and std 0.596526
# hidden layer 4 had mean 0.000393 and std 0.577709
# hidden layer 5 had mean -0.000863 and std 0.568061
# hidden layer 6 had mean 0.001686 and std 0.563840
# hidden layer 7 had mean -0.001313 and std 0.560791
# hidden layer 8 had mean 0.000711 and std 0.559290
# hidden layer 9 had mean 0.000393 and std 0.558076
# hidden layer 10 had mean -0.001139 and std 0.557800
